# %%
# Importing libraries in Python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\karth\Desktop\Decoder Lecture\Sessions\Day 19\gapminder.csv")

# %%
df.head()
# Out:
#    population  fertility  HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 0  34811059.0       2.73  0.1   3.328945  24.59620  12314.0    129.9049  75.3
# 1  19842251.0       6.43  2.0   1.474353  22.25083   7103.0    130.1247  58.3
# 2  40381860.0       2.24  0.5   4.785170  27.50170  14646.0    118.8915  75.5
# 3   2975029.0       1.40  0.1   1.804106  25.35542   7383.0    132.8108  72.5
# 4  21370348.0       1.96  0.1  18.016313  27.56373  41312.0    117.3755  81.5
#
#    child_mortality                      Region
# 0             29.5  Middle East & North Africa
# 1            192.0          Sub-Saharan Africa
# 2             15.4                     America
# 3             20.0       Europe & Central Asia
# 4              5.2         East Asia & Pacific

# %%
y=df["fertility"]

# %%
X=df.drop("fertility",axis=1)

# %%
X=pd.get_dummies(X,columns=["Region"])     #drop_first for Trees normal it doesnt matter

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   population                         139 non-null    float64
#  1   HIV                                139 non-null    float64
#  2   CO2                                139 non-null    float64
#  3   BMI_male                           139 non-null    float64
#  4   GDP                                139 non-null    float64
#  5   BMI_female                         139 non-null    float64
#  6   life                               139 non-null    float64
#  7   child_mortality                    139 non-null    float64
#  8   Region_America                     139 non-null    uint8
#  9   Region_East Asia & Pacific         139 non-null    uint8
#  10  Region_Europe & Central Asia       139 non-null    uint8
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=43,test_size=.30)

# %%
X_train.shape
# Out:
# (97, 14)

# %%
X_test.shape
# Out:
# (42, 14)

# %%
X_test
# Out:
#       population    HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 95     2652281.0   0.10  15.572080  26.24109  47799.0    126.8870  74.6
# 37     6004199.0   0.80   1.067765  26.36751   7450.0    119.9321  74.1
# 57      310033.0   0.30   6.821903  27.20687  42294.0    118.7381  82.0
# 82   114972821.0   0.30   4.261172  27.42468  15826.0    122.1216  75.7
# 105   20741669.0   0.10   4.383449  25.41069  18032.0    128.7553  73.4
# 11    10779155.0   0.20   9.797337  26.75915  41641.0    121.8227  79.4
# 45     1586749.0   1.70   0.251002  21.65029   1566.0    130.2080  62.2
# 126    6052937.0   3.20   0.251983  21.87875   1219.0    131.0248  60.0
# 83     4111168.0   0.40   1.313321  24.23690   3890.0    129.9424  69.6
# 54     9705130.0   2.00   0.249307  23.66302   1600.0    125.3461  61.7
# 108   12229703.0   0.80   0.461634  21.92743   2162.0    130.2795  64.3
# 77      321026.0   0.06   3.277726  23.21991  12029.0    123.3223  78.2
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
standardscaler=StandardScaler()

# %%
X_train=standardscaler.fit_transform(X_train)

# %%
X_test=standardscaler.transform(X_test)

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
model=AdaBoostRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
model.score(X_test,y_test)
# Out:
# 0.8838550607248105
